# %%
#importar bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#importar o DataSet
dados = pd.read_csv('./IceCreamData.csv')

# cabeçalho
dados.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
#últimas linhas
dados.tail(1) # 1 'linha'
# Out:
#      Temperature     Revenue
# 499    28.957736  655.660388

# %%
#describe

dados.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
#info de tipos de dados 
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
### Gerar algumas visualizações GRÁFICA

sns.jointplot(data = dados, x= 'Temperature', y ='Revenue', color = "pink")

# %%
sns.pairplot(dados)

# %%
#gráfico de dispersão e linhas tendência
sns.lmplot(x='Temperature', y='Revenue',data= dados)

# %%
#Criar e testar o modelo
#criação da variavel dependente ou variavel resposta (y)
y= dados['Revenue']

#Criação da variável independente ou variavel entrada (x)
x= dados[['Temperature']]

#Separar os dados para teste e treino
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.25)

# %%
#Treinamento do modelo

#criação do modelo
modelo = LinearRegression()

# Treinamento do modelo
modelo.fit(x_train, y_train)

#Exibição dos coeficientes
print('Coeficiente linear(b):', modelo.intercept_)
print('Coeficiente angular (a):', modelo.coef_)
# Out:
# Coeficiente linear(b): 44.31065990659283
# Coeficiente angular (a): [21.48316103]

# %%
#Testando o modelo
y_predict = modelo.predict(x_test)
y_predict
# Out:
# array([528.25644589, 750.95825458, 456.18678955, 539.63100885,
#        447.66470099, 576.27403873, 666.41437242, 745.73449723,
#        663.66501677, 441.88300403, 399.98249875, 408.55288231,
#        424.34845788, 447.62547575, 210.70388541, 667.1877819 ,
#        698.61769977, 158.33269493, 420.63278083, 495.60839305,
#        670.09640276, 454.93234116, 412.377262  , 720.41203988,
#        449.99263437, 547.28619449, 839.12497195, 832.79792709,
#        493.32107359, 628.34780061, 573.12379591, 776.06307462,
#        874.18073202, 484.17886629, 365.08660283, 546.6974852 ,
#        450.52476647, 493.23609544, 572.08499398, 306.61325971,
#        525.49001263, 601.48450049, 543.7236275 , 580.53993348,
#        690.54754625, 567.40638108, 352.64802682, 644.36430923,
#        510.58017468, 639.98284238, 475.05203256, 628.40595188,
#        249.63115678, 635.45518993, 452.02454031, 547.17253074,
#        526.56538727, 393.59937576, 517.15233403, 415.15687669,
# ...

# %%
minha_previsao = modelo.predict([[41]])

minha_previsao
# Out:
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([925.12026226])
